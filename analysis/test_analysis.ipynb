# %%
import pandas as pd

df = pd.read_csv("../output/input_2020-03-01.csv.gz")

# %%
df.describe()
# Out:
#           practice  flucats_clinical_concern_note  flucats_template  \
# count  1000.000000                     1000.00000        1000.00000
# mean     11.942000                        0.50000           0.50000
# std      12.424452                        0.50025           0.50025
# min       0.000000                        0.00000           0.00000
# 25%       0.000000                        0.00000           0.00000
# 50%       5.500000                        0.50000           0.50000
# 75%      24.000000                        1.00000           1.00000
# max      38.000000                        1.00000           1.00000
#
#        flucats_question_8_code  flucats_question_13_code  \
# count             2.460000e+02              2.270000e+02
# mean              6.952773e+14              4.388545e+14
# std               4.131396e+14              4.699146e+14
# min               8.176501e+07              6.231501e+07
# 25%               8.176501e+07              6.231501e+07
# ...
